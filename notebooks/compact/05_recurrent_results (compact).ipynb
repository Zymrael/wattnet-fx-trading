# %%
import os
from copy import deepcopy
import math
import natsort
import random
import pathlib
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from umap import UMAP
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.nn.parameter import Parameter
from torch.utils.data import TensorDataset, Dataset, DataLoader

from torchNDF.metrics import *
from torchNDF.models.recurrent_wrapper import *
from torchNDF.data.torch_utils import *
from torchNDF.data.datahandler import FXDataHandler
from torchNDF.vis import *

# %% [markdown]
# ## In this notebook:
#
# * Static training and evaluation
# * Rolling training and evaluation
# * Trade activity plot and performance comparison
# * Explainability plots: input gradients and UMAP

# %%
CURR_IDX = 1
TECH_START_IDX = 65
LABEL_START_IDX = 1123
CURRENCIES = ['USDCNY', 'USDIDR', 'USDINR', 'USDKRW', 'USDPHP', 'USDTWD']
CURR_N = CURRENCIES[CURR_IDX]

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# ### Data prep:

# %%
PATH = Path('../../data/final').resolve()
input_data = pd.read_pickle(f'{PATH}/input_data_labels')
returns = pd.read_pickle(f'{PATH}/returns')
expert_oracle_labels = pd.read_pickle(f'{PATH}/expert_oracle_labels')

# %%
data, expert_labels = input_data.iloc[:, :LABEL_START_IDX], input_data.iloc[:, LABEL_START_IDX:]
dh = FXDataHandler()
dh.assign_data(data)
dh.split_train_val_test([60, 30, 10])
dh.to_tensor(device=device)
train, val, test = dh.datasets

len_slice = 30
bs = 32

trainloader = DataLoader(RegularFinancialData(train, len_slice),
                         batch_size=bs, shuffle=True)


valloader = DataLoader(RegularFinancialData(val, len_slice), 
                       batch_size=len(val), shuffle=False)

# %%
# split returns into train, val, test returns
len(train), len(val), len(test)
# Out:
# (892, 446, 148)

# %%
# returns from last day for sequence of length `len_slice`
train_returns = returns[:, len_slice:len(train)+len_slice, :]

val_returns = returns[:, len_slice+len(train): \
                 len(train)+len(val), :]

test_returns = returns[:, len_slice+len(train)+len(val): \
                  len(train)+len(val)+len(test), :]

# %% [markdown]
# ## Static Validation

# %%
train_returns_single = torch.Tensor(train_returns[:, :, CURR_IDX]).to(device)
val_returns_single = torch.Tensor(val_returns[:, :, CURR_IDX]).to(device)

ensemble_size=1
ensemble = []

# seeds
seed_list = []
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

for _ in range(ensemble_size):
    torch.manual_seed(_)
    np.random.seed(_)
    torch.cuda.manual_seed_all(_)
    seed_list.append((_, _, _))
    
    m = RecurrentWrapper(seq_len = len_slice,
                         rec_cell_type='GRU',
                         in_dim=1123,
                         latent_dim=512, 
                         n_recurrent_layers=2,
                         mlp_in_dim=512, 
                         mlp_out_dim=91, 
                         mlp_layers=[128],
                         dropout_prob=0.2,
                        ).to(device)
    
    opt = torch.optim.Adam(m.parameters(), lr=0.006, weight_decay=0.0003)
    sched = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(opt, 200, eta_min=0.003, T_mult=2)
    m.fit(epochs=200, 
          trainloader=trainloader, 
          valloader=valloader, 
          opt=opt, 
          sched=sched, 
          device=device, 
          log_interval=1000, 
          dropout_schedule=[0.2, 0.2, 0., 0.], 
          dropout_interval=50,
          tr_returns=train_returns_single,
          val_returns=val_returns_single
          )
    
    ensemble.append(m)
# Out:
# Epoch: 0
# Training Loss: 4.53
# Avg train returns: 0.1
# Avg train optimal returns: 1.19
#
# Validation Loss: 4.72
# Validation Accuracy: 1.68
# Avg val returns: 2.61
# Avg val optimal returns: 12.6
#
# Epoch: 1
# Training Loss: 4.23
# Avg train returns: 0.81
# Avg train optimal returns: 1.36
#
# Validation Loss: 7.48
# Validation Accuracy: 4.57
# Avg val returns: 2.5
# Avg val optimal returns: 12.6
#
# Epoch: 2
# Training Loss: 3.73
# Avg train returns: 0.56
# Avg train optimal returns: 1.3
#
# Validation Loss: 8.67
# Validation Accuracy: 3.12
# Avg val returns: 1.12
# Avg val optimal returns: 12.6
#
# Epoch: 3
# Training Loss: 3.76
# Avg train returns: 0.59
# Avg train optimal returns: 1.37
#
# Validation Loss: 11.68
# Validation Accuracy: 3.37
# Avg val returns: 1.31
# Avg val optimal returns: 12.6
#
# Epoch: 4
# Training Loss: 3.71
# Avg train returns: 0.7
# Avg train optimal returns: 1.27
#
# Validation Loss: 8.67
# Validation Accuracy: 2.4
# Avg val returns: 0.56
# Avg val optimal returns: 12.6
#
# Epoch: 5
# Training Loss: 3.67
# Avg train returns: 0.81
# Avg train optimal returns: 1.36
#
# Validation Loss: 8.83
# Validation Accuracy: 2.64
# Avg val returns: 1.22
# Avg val optimal returns: 12.6
#
# Epoch: 6
# Training Loss: 3.56
# Avg train returns: 0.89
# Avg train optimal returns: 1.3
#
# Validation Loss: 12.55
# Validation Accuracy: 1.68
# Avg val returns: 1.45
# Avg val optimal returns: 12.6
#
# Epoch: 7
# Training Loss: 3.37
# Avg train returns: 0.49
# Avg train optimal returns: 0.98
#
# Validation Loss: 16.8
# Validation Accuracy: 1.44
# Avg val returns: 1.03
# Avg val optimal returns: 12.6
#
# Epoch: 8
# Training Loss: 3.47
# Avg train returns: 0.78
# Avg train optimal returns: 1.29
#
# Validation Loss: 16.96
# Validation Accuracy: 2.16
# Avg val returns: 0.67
# Avg val optimal returns: 12.6
#
# Epoch: 9
# Training Loss: 3.26
# Avg train returns: 0.79
# Avg train optimal returns: 1.2
#
# Validation Loss: 19.6
# Validation Accuracy: 1.2
# Avg val returns: -0.42
# Avg val optimal returns: 12.6
#
# Epoch: 10
# Training Loss: 3.47
# Avg train returns: 0.9
# Avg train optimal returns: 1.49
#
# Validation Loss: 14.09
# Validation Accuracy: 1.68
# Avg val returns: 1.06
# Avg val optimal returns: 12.6
#
# Epoch: 11
# Training Loss: 3.21
# Avg train returns: 0.78
# Avg train optimal returns: 1.26
#
# Validation Loss: 20.76
# Validation Accuracy: 1.92
# Avg val returns: 1.16
# Avg val optimal returns: 12.6
#
# Epoch: 12
# Training Loss: 3.12
# Avg train returns: 1.2
# Avg train optimal returns: 1.51
#
# Validation Loss: 8.84
# Validation Accuracy: 0.96
# Avg val returns: 0.99
# Avg val optimal returns: 12.6
#
# Epoch: 13
# Training Loss: 3.14
# Avg train returns: 0.93
# Avg train optimal returns: 1.35
#
# Validation Loss: 15.41
# Validation Accuracy: 0.96
# Avg val returns: 1.02
# Avg val optimal returns: 12.6
#
# Epoch: 14
# Training Loss: 2.93
# Avg train returns: 0.81
# Avg train optimal returns: 1.09
#
# Validation Loss: 27.58
# Validation Accuracy: 1.2
# Avg val returns: 0.59
# Avg val optimal returns: 12.6
#
# Epoch: 15
# Training Loss: 2.92
# Avg train returns: 1.12
# Avg train optimal returns: 1.35
#
# Validation Loss: 23.32
# Validation Accuracy: 0.96
# Avg val returns: 0.53
# Avg val optimal returns: 12.6
#
# Epoch: 16
# Training Loss: 3.3
# Avg train returns: 0.86
# Avg train optimal returns: 1.2
#
# Validation Loss: 27.36
# Validation Accuracy: 0.48
# Avg val returns: 1.58
# Avg val optimal returns: 12.6
#
# Epoch: 17
# Training Loss: 3.13
# Avg train returns: 0.69
# Avg train optimal returns: 1.1
#
# Validation Loss: 35.35
# Validation Accuracy: 1.44
# Avg val returns: 1.96
# Avg val optimal returns: 12.6
#
# Epoch: 18
# Training Loss: 3.0
# Avg train returns: 0.6
# Avg train optimal returns: 0.99
#
# Validation Loss: 38.25
# Validation Accuracy: 0.48
# Avg val returns: 0.14
# Avg val optimal returns: 12.6
#
# Epoch: 19
# Training Loss: 2.93
# Avg train returns: 1.12
# Avg train optimal returns: 1.45
#
# Validation Loss: 42.81
# Validation Accuracy: 1.92
# Avg val returns: 1.01
# Avg val optimal returns: 12.6
#
# Epoch: 20
# Training Loss: 3.12
# Avg train returns: 0.92
# Avg train optimal returns: 1.38
#
# Validation Loss: 48.48
# Validation Accuracy: 0.48
# Avg val returns: 0.29
# Avg val optimal returns: 12.6
#
# Epoch: 21
# Training Loss: 2.94
# Avg train returns: 0.72
# Avg train optimal returns: 1.07
#
# Validation Loss: 8.2
# Validation Accuracy: 0.0
# Avg val returns: -0.38
# Avg val optimal returns: 12.6
#
# Epoch: 22
# Training Loss: 3.12
# Avg train returns: 0.69
# Avg train optimal returns: 1.01
#
# Validation Loss: 9.0
# Validation Accuracy: 0.96
# Avg val returns: 0.63
# Avg val optimal returns: 12.6
#
# Epoch: 23
# Training Loss: 3.14
# Avg train returns: 1.09
# Avg train optimal returns: 1.41
#
# Validation Loss: 12.76
# Validation Accuracy: 2.64
# Avg val returns: 1.09
# Avg val optimal returns: 12.6
#
# Epoch: 24
# Training Loss: 2.67
# Avg train returns: 0.7
# Avg train optimal returns: 1.12
#
# Validation Loss: 22.0
# Validation Accuracy: 1.2
# Avg val returns: 1.04
# Avg val optimal returns: 12.6
#
# Epoch: 25
# Training Loss: 3.01
# Avg train returns: 1.02
# Avg train optimal returns: 1.36
#
# Validation Loss: 28.85
# Validation Accuracy: 0.72
# Avg val returns: 0.07
# Avg val optimal returns: 12.6
#
# Epoch: 26
# Training Loss: 2.87
# Avg train returns: 0.7
# Avg train optimal returns: 1.04
#
# Validation Loss: 24.49
# Validation Accuracy: 0.96
# Avg val returns: 1.42
# Avg val optimal returns: 12.6
#
# Epoch: 27
# Training Loss: 3.02
# Avg train returns: 0.74
# Avg train optimal returns: 1.1
#
# Validation Loss: 19.42
# Validation Accuracy: 0.96
# Avg val returns: 0.63
# Avg val optimal returns: 12.6
#
# Epoch: 28
# Training Loss: 2.91
# Avg train returns: 0.73
# Avg train optimal returns: 1.11
#
# Validation Loss: 30.22
# Validation Accuracy: 1.68
# Avg val returns: 0.69
# Avg val optimal returns: 12.6
#
# Epoch: 29
# Training Loss: 3.0
# Avg train returns: 0.83
# Avg train optimal returns: 1.09
#
# Validation Loss: 35.06
# Validation Accuracy: 0.48
# Avg val returns: 0.44
# Avg val optimal returns: 12.6
#
# Epoch: 30
# Training Loss: 3.02
# Avg train returns: 0.55
# Avg train optimal returns: 0.88
#
# Validation Loss: 38.63
# Validation Accuracy: 0.72
# Avg val returns: 1.3
# Avg val optimal returns: 12.6
#
# Epoch: 31
# Training Loss: 3.29
# Avg train returns: 1.15
# Avg train optimal returns: 1.52
#
# Validation Loss: 20.54
# Validation Accuracy: 0.96
# Avg val returns: 1.81
# Avg val optimal returns: 12.6
#
# Epoch: 32
# Training Loss: 2.94
# Avg train returns: 1.09
# Avg train optimal returns: 1.46
#
# Validation Loss: 20.12
# Validation Accuracy: 0.96
# Avg val returns: 0.72
# Avg val optimal returns: 12.6
#
# Epoch: 33
# Training Loss: 3.04
# Avg train returns: 0.81
# Avg train optimal returns: 1.28
#
# Validation Loss: 19.49
# Validation Accuracy: 1.2
# Avg val returns: 1.8
# Avg val optimal returns: 12.6
#
# Epoch: 34
# Training Loss: 2.73
# Avg train returns: 0.94
# Avg train optimal returns: 1.22
#
# Validation Loss: 11.95
# Validation Accuracy: 0.72
# Avg val returns: 2.06
# Avg val optimal returns: 12.6
#
# Epoch: 35
# Training Loss: 2.71
# Avg train returns: 0.96
# Avg train optimal returns: 1.24
#
# Validation Loss: 16.18
# Validation Accuracy: 0.48
# Avg val returns: 2.65
# Avg val optimal returns: 12.6
#
# Epoch: 36
# Training Loss: 3.03
# Avg train returns: 0.9
# Avg train optimal returns: 1.3
#
# Validation Loss: 17.82
# Validation Accuracy: 0.72
# Avg val returns: 2.69
# Avg val optimal returns: 12.6
#
# Epoch: 37
# Training Loss: 2.94
# Avg train returns: 0.57
# Avg train optimal returns: 0.99
#
# Validation Loss: 17.05
# Validation Accuracy: 1.2
# Avg val returns: 2.47
# Avg val optimal returns: 12.6
#
# Epoch: 38
# Training Loss: 2.86
# Avg train returns: 1.23
# Avg train optimal returns: 1.6
#
# Validation Loss: 18.86
# Validation Accuracy: 0.24
# Avg val returns: 1.0
# Avg val optimal returns: 12.6
#
# Epoch: 39
# Training Loss: 2.87
# Avg train returns: 1.22
# Avg train optimal returns: 1.42
#
# Validation Loss: 19.36
# Validation Accuracy: 0.96
# Avg val returns: 0.69
# Avg val optimal returns: 12.6
#
# Epoch: 40
# Training Loss: 3.03
# Avg train returns: 0.88
# Avg train optimal returns: 1.28
#
# Validation Loss: 23.37
# Validation Accuracy: 0.0
# Avg val returns: 0.58
# Avg val optimal returns: 12.6
#
# Epoch: 41
# Training Loss: 2.87
# Avg train returns: 0.73
# Avg train optimal returns: 1.13
#
# Validation Loss: 23.42
# Validation Accuracy: 1.2
# Avg val returns: 0.84
# Avg val optimal returns: 12.6
#
# Epoch: 42
# Training Loss: 2.86
# Avg train returns: 0.73
# Avg train optimal returns: 1.09
#
# Validation Loss: 22.46
# Validation Accuracy: 0.48
# Avg val returns: 1.58
# Avg val optimal returns: 12.6
#
# Epoch: 43
# Training Loss: 3.17
# Avg train returns: 0.75
# Avg train optimal returns: 1.06
#
# Validation Loss: 16.42
# Validation Accuracy: 0.48
# Avg val returns: 0.39
# Avg val optimal returns: 12.6
# Epoch: 44
# Training Loss: 2.87
# Avg train returns: 0.9
# Avg train optimal returns: 1.21
#
# Validation Loss: 22.62
# Validation Accuracy: 0.48
# Avg val returns: -0.14
# Avg val optimal returns: 12.6
#
# Epoch: 45
# Training Loss: 3.03
# Avg train returns: 0.92
# Avg train optimal returns: 1.24
#
# Validation Loss: 14.26
# Validation Accuracy: 0.24
# Avg val returns: 1.58
# Avg val optimal returns: 12.6
#
# Epoch: 46
# Training Loss: 2.66
# Avg train returns: 0.9
# Avg train optimal returns: 1.13
#
# Validation Loss: 15.87
# Validation Accuracy: 1.2
# Avg val returns: 1.43
# Avg val optimal returns: 12.6
#
# Epoch: 47
# Training Loss: 2.91
# Avg train returns: 0.96
# Avg train optimal returns: 1.29
#
# Validation Loss: 19.47
# Validation Accuracy: 0.72
# Avg val returns: 0.74
# Avg val optimal returns: 12.6
#
# Epoch: 48
# Training Loss: 3.06
# Avg train returns: 0.77
# Avg train optimal returns: 1.07
#
# Validation Loss: 20.71
# Validation Accuracy: 0.48
# Avg val returns: 1.87
# Avg val optimal returns: 12.6
#
# Epoch: 49
# Training Loss: 2.83
# Avg train returns: 0.88
# Avg train optimal returns: 1.18
#
# Validation Loss: 20.66
# Validation Accuracy: 0.48
# Avg val returns: 1.62
# Avg val optimal returns: 12.6
#
# Epoch: 50
# Training Loss: 2.51
# Avg train returns: 0.92
# Avg train optimal returns: 1.25
#
# Validation Loss: 29.24
# Validation Accuracy: 0.72
# Avg val returns: 0.84
# Avg val optimal returns: 12.6
#
# Epoch: 51
# Training Loss: 2.75
# Avg train returns: 0.84
# Avg train optimal returns: 1.12
#
# Validation Loss: 34.3
# Validation Accuracy: 0.96
# Avg val returns: 1.24
# Avg val optimal returns: 12.6
#
# Epoch: 52
# Training Loss: 2.54
# Avg train returns: 0.74
# Avg train optimal returns: 0.98
#
# Validation Loss: 16.34
# Validation Accuracy: 0.96
# Avg val returns: 1.15
# Avg val optimal returns: 12.6
#
# Epoch: 53
# Training Loss: 3.04
# Avg train returns: 0.69
# Avg train optimal returns: 1.05
#
# Validation Loss: 15.65
# Validation Accuracy: 0.24
# Avg val returns: 0.62
# Avg val optimal returns: 12.6
#
# Epoch: 54
# Training Loss: 2.63
# Avg train returns: 0.98
# Avg train optimal returns: 1.22
#
# Validation Loss: 17.1
# Validation Accuracy: 0.48
# Avg val returns: 0.61
# Avg val optimal returns: 12.6
#
# Epoch: 55
# Training Loss: 3.01
# Avg train returns: 1.12
# Avg train optimal returns: 1.33
#
# Validation Loss: 19.84
# Validation Accuracy: 0.0
# Avg val returns: 1.02
# Avg val optimal returns: 12.6
#
# Epoch: 56
# Training Loss: 2.74
# Avg train returns: 0.99
# Avg train optimal returns: 1.24
#
# Validation Loss: 11.72
# Validation Accuracy: 1.44
# Avg val returns: 1.62
# Avg val optimal returns: 12.6
#
# Epoch: 57
# Training Loss: 2.48
# Avg train returns: 0.9
# Avg train optimal returns: 1.09
#
# Validation Loss: 14.89
# Validation Accuracy: 0.96
# Avg val returns: 1.55
# Avg val optimal returns: 12.6
#
# Epoch: 58
# Training Loss: 2.86
# Avg train returns: 0.89
# Avg train optimal returns: 1.17
#
# Validation Loss: 9.87
# Validation Accuracy: 0.0
# Avg val returns: 1.26
# Avg val optimal returns: 12.6
#
# Epoch: 59
# Training Loss: 2.76
# Avg train returns: 0.77
# Avg train optimal returns: 1.08
#
# Validation Loss: 15.12
# Validation Accuracy: 0.48
# Avg val returns: 1.87
# Avg val optimal returns: 12.6
#
# Epoch: 60
# Training Loss: 2.63
# Avg train returns: 0.69
# Avg train optimal returns: 1.0
#
# Validation Loss: 12.03
# Validation Accuracy: 0.0
# Avg val returns: 2.21
# Avg val optimal returns: 12.6
#
# Epoch: 61
# Training Loss: 2.68
# Avg train returns: 1.11
# Avg train optimal returns: 1.4
#
# Validation Loss: 24.77
# Validation Accuracy: 0.48
# Avg val returns: 1.06
# Avg val optimal returns: 12.6
#
# Epoch: 62
# Training Loss: 2.87
# Avg train returns: 0.77
# Avg train optimal returns: 1.05
#
# Validation Loss: 8.16
# Validation Accuracy: 0.72
# Avg val returns: 0.79
# Avg val optimal returns: 12.6
#
# Epoch: 63
# Training Loss: 2.66
# Avg train returns: 1.04
# Avg train optimal returns: 1.3
#
# Validation Loss: 10.04
# Validation Accuracy: 0.0
# Avg val returns: 0.61
# Avg val optimal returns: 12.6
#
# Epoch: 64
# Training Loss: 2.84
# Avg train returns: 0.86
# Avg train optimal returns: 1.21
#
# Validation Loss: 10.7
# Validation Accuracy: 0.48
# Avg val returns: 1.32
# Avg val optimal returns: 12.6
#
# Epoch: 65
# Training Loss: 2.83
# Avg train returns: 1.0
# Avg train optimal returns: 1.5
#
# Validation Loss: 10.57
# Validation Accuracy: 0.72
# Avg val returns: 1.02
# Avg val optimal returns: 12.6
#
# Epoch: 66
# Training Loss: 2.38
# Avg train returns: 0.67
# Avg train optimal returns: 0.95
#
# Validation Loss: 13.29
# Validation Accuracy: 0.72
# Avg val returns: 0.29
# Avg val optimal returns: 12.6
#
# Epoch: 67
# Training Loss: 2.93
# Avg train returns: 0.87
# Avg train optimal returns: 1.25
#
# Validation Loss: 18.82
# Validation Accuracy: 0.48
# Avg val returns: 0.47
# Avg val optimal returns: 12.6
#
# Epoch: 68
# Training Loss: 2.78
# Avg train returns: 0.9
# Avg train optimal returns: 1.28
#
# Validation Loss: 23.47
# Validation Accuracy: 0.72
# Avg val returns: 1.25
# Avg val optimal returns: 12.6
#
# Epoch: 69
# Training Loss: 2.96
# Avg train returns: 0.95
# Avg train optimal returns: 1.26
#
# Validation Loss: 26.32
# Validation Accuracy: 0.0
# Avg val returns: 0.16
# Avg val optimal returns: 12.6
#
# Epoch: 70
# Training Loss: 2.83
# Avg train returns: 0.85
# Avg train optimal returns: 1.18
#
# Validation Loss: 30.73
# Validation Accuracy: 0.24
# Avg val returns: -0.37
# Avg val optimal returns: 12.6
#
# Epoch: 71
# Training Loss: 2.5
# Avg train returns: 0.94
# Avg train optimal returns: 1.26
#
# Validation Loss: 24.5
# Validation Accuracy: 0.24
# Avg val returns: 0.17
# Avg val optimal returns: 12.6
#
# Epoch: 72
# Training Loss: 2.66
# Avg train returns: 0.81
# Avg train optimal returns: 1.07
#
# Validation Loss: 25.43
# Validation Accuracy: 0.0
# Avg val returns: -0.11
# Avg val optimal returns: 12.6
#
# Epoch: 73
# Training Loss: 2.8
# Avg train returns: 1.26
# Avg train optimal returns: 1.48
#
# Validation Loss: 26.7
# Validation Accuracy: 0.24
# Avg val returns: -0.45
# Avg val optimal returns: 12.6
#
# Epoch: 74
# Training Loss: 2.6
# Avg train returns: 1.02
# Avg train optimal returns: 1.32
#
# Validation Loss: 29.06
# Validation Accuracy: 0.48
# Avg val returns: -0.62
# Avg val optimal returns: 12.6
#
# Epoch: 75
# Training Loss: 2.52
# Avg train returns: 0.82
# Avg train optimal returns: 1.16
#
# Validation Loss: 32.71
# Validation Accuracy: 0.0
# Avg val returns: -0.74
# Avg val optimal returns: 12.6
#
# Epoch: 76
# Training Loss: 3.01
# Avg train returns: 0.94
# Avg train optimal returns: 1.28
#
# Validation Loss: 29.4
# Validation Accuracy: 0.24
# Avg val returns: -0.34
# Avg val optimal returns: 12.6
#
# Epoch: 77
# Training Loss: 2.86
# Avg train returns: 0.92
# Avg train optimal returns: 1.19
#
# Validation Loss: 22.73
# Validation Accuracy: 0.48
# Avg val returns: 0.52
# Avg val optimal returns: 12.6
#
# Epoch: 78
# Training Loss: 2.74
# Avg train returns: 0.91
# Avg train optimal returns: 1.12
#
# Validation Loss: 25.85
# Validation Accuracy: 0.0
# Avg val returns: 0.96
# Avg val optimal returns: 12.6
#
# Epoch: 79
# Training Loss: 2.69
# Avg train returns: 1.13
# Avg train optimal returns: 1.43
#
# Validation Loss: 16.95
# Validation Accuracy: 0.24
# Avg val returns: -0.0
# Avg val optimal returns: 12.6
#
# Epoch: 80
# Training Loss: 2.71
# Avg train returns: 0.72
# Avg train optimal returns: 1.08
#
# Validation Loss: 15.87
# Validation Accuracy: 0.48
# Avg val returns: 0.37
# Avg val optimal returns: 12.6
#
# Epoch: 81
# Training Loss: 2.49
# Avg train returns: 0.86
# Avg train optimal returns: 1.08
#
# Validation Loss: 19.24
# Validation Accuracy: 0.48
# Avg val returns: 0.78
# Avg val optimal returns: 12.6
#
# Epoch: 82
# Training Loss: 2.82
# Avg train returns: 0.85
# Avg train optimal returns: 1.19
#
# Validation Loss: 23.44
# Validation Accuracy: 1.2
# Avg val returns: 0.37
# Avg val optimal returns: 12.6
#
# Epoch: 83
# Training Loss: 2.98
# Avg train returns: 0.77
# Avg train optimal returns: 1.18
#
# Validation Loss: 26.78
# Validation Accuracy: 0.24
# Avg val returns: 0.99
# Avg val optimal returns: 12.6
#
# Epoch: 84
# Training Loss: 2.74
# Avg train returns: 0.86
# Avg train optimal returns: 1.29
#
# Validation Loss: 30.58
# Validation Accuracy: 0.24
# Avg val returns: -0.14
# Avg val optimal returns: 12.6
#
# Epoch: 85
# Training Loss: 2.17
# Avg train returns: 0.92
# Avg train optimal returns: 1.2
#
# Validation Loss: 23.24
# Validation Accuracy: 0.24
# Avg val returns: -0.6
# Avg val optimal returns: 12.6
#
# Epoch: 86
# Training Loss: 2.64
# Avg train returns: 0.9
# Avg train optimal returns: 1.2
#
# Validation Loss: 20.41
# Validation Accuracy: 0.48
# Avg val returns: -0.31
# Avg val optimal returns: 12.6
#
# Epoch: 87
# Training Loss: 2.51
# Avg train returns: 1.16
# Avg train optimal returns: 1.41
#
# Validation Loss: 14.77
# Validation Accuracy: 0.24
# Avg val returns: 0.87
# Avg val optimal returns: 12.6
# Epoch: 88
# Training Loss: 2.56
# Avg train returns: 0.95
# Avg train optimal returns: 1.2
#
# Validation Loss: 18.8
# Validation Accuracy: 0.24
# Avg val returns: 0.47
# Avg val optimal returns: 12.6
#
# Epoch: 89
# Training Loss: 2.75
# Avg train returns: 1.15
# Avg train optimal returns: 1.51
#
# Validation Loss: 22.04
# Validation Accuracy: 0.48
# Avg val returns: 0.13
# Avg val optimal returns: 12.6
#
# Epoch: 90
# Training Loss: 2.36
# Avg train returns: 0.9
# Avg train optimal returns: 1.2
#
# Validation Loss: 17.32
# Validation Accuracy: 0.48
# Avg val returns: 0.12
# Avg val optimal returns: 12.6
#
# Epoch: 91
# Training Loss: 2.53
# Avg train returns: 1.26
# Avg train optimal returns: 1.49
#
# Validation Loss: 20.51
# Validation Accuracy: 0.24
# Avg val returns: 0.04
# Avg val optimal returns: 12.6
#
# Epoch: 92
# Training Loss: 2.71
# Avg train returns: 1.1
# Avg train optimal returns: 1.49
#
# Validation Loss: 23.3
# Validation Accuracy: 0.0
# Avg val returns: -0.03
# Avg val optimal returns: 12.6
#
# Epoch: 93
# Training Loss: 2.4
# Avg train returns: 1.24
# Avg train optimal returns: 1.47
#
# Validation Loss: 27.06
# Validation Accuracy: 0.0
# Avg val returns: 1.05
# Avg val optimal returns: 12.6
#
# Epoch: 94
# Training Loss: 2.91
# Avg train returns: 1.04
# Avg train optimal returns: 1.41
#
# Validation Loss: 29.35
# Validation Accuracy: 0.24
# Avg val returns: 0.74
# Avg val optimal returns: 12.6
#
# Epoch: 95
# Training Loss: 2.71
# Avg train returns: 1.03
# Avg train optimal returns: 1.31
#
# Validation Loss: 37.05
# Validation Accuracy: 0.0
# Avg val returns: -0.19
# Avg val optimal returns: 12.6
#
# Epoch: 96
# Training Loss: 2.6
# Avg train returns: 0.81
# Avg train optimal returns: 1.2
#
# Validation Loss: 28.12
# Validation Accuracy: 0.48
# Avg val returns: 1.66
# Avg val optimal returns: 12.6
#
# Epoch: 97
# Training Loss: 2.48
# Avg train returns: 0.98
# Avg train optimal returns: 1.23
#
# Validation Loss: 24.21
# Validation Accuracy: 0.24
# Avg val returns: 1.09
# Avg val optimal returns: 12.6
#
# Epoch: 98
# Training Loss: 2.83
# Avg train returns: 0.66
# Avg train optimal returns: 0.93
#
# Validation Loss: 33.74
# Validation Accuracy: 0.24
# Avg val returns: 1.53
# Avg val optimal returns: 12.6
#
# Epoch: 99
# Training Loss: 2.87
# Avg train returns: 0.73
# Avg train optimal returns: 1.18
#
# Validation Loss: 35.92
# Validation Accuracy: 0.24
# Avg val returns: 0.59
# Avg val optimal returns: 12.6
#
# Epoch: 100
# Training Loss: 2.62
# Avg train returns: 1.05
# Avg train optimal returns: 1.32
#
# Validation Loss: 37.32
# Validation Accuracy: 0.0
# Avg val returns: -0.18
# Avg val optimal returns: 12.6
#
# Epoch: 101
# Training Loss: 2.33
# Avg train returns: 1.25
# Avg train optimal returns: 1.43
#
# Validation Loss: 42.74
# Validation Accuracy: 0.48
# Avg val returns: -0.08
# Avg val optimal returns: 12.6
#
# Epoch: 102
# Training Loss: 2.98
# Avg train returns: 0.59
# Avg train optimal returns: 1.1
#
# Validation Loss: 43.29
# Validation Accuracy: 0.96
# Avg val returns: 0.76
# Avg val optimal returns: 12.6
#
# Epoch: 103
# Training Loss: 2.48
# Avg train returns: 1.15
# Avg train optimal returns: 1.45
#
# Validation Loss: 41.27
# Validation Accuracy: 0.48
# Avg val returns: 0.53
# Avg val optimal returns: 12.6
#
# Epoch: 104
# Training Loss: 2.76
# Avg train returns: 0.94
# Avg train optimal returns: 1.2
#
# Validation Loss: 47.24
# Validation Accuracy: 0.0
# Avg val returns: 0.48
# Avg val optimal returns: 12.6
#
# Epoch: 105
# Training Loss: 2.74
# Avg train returns: 0.85
# Avg train optimal returns: 1.28
#
# Validation Loss: 38.76
# Validation Accuracy: 0.24
# Avg val returns: 0.68
# Avg val optimal returns: 12.6
#
# Epoch: 106
# Training Loss: 2.6
# Avg train returns: 1.03
# Avg train optimal returns: 1.32
#
# Validation Loss: 40.39
# Validation Accuracy: 0.72
# Avg val returns: 0.25
# Avg val optimal returns: 12.6
#
# Epoch: 107
# Training Loss: 2.44
# Avg train returns: 1.03
# Avg train optimal returns: 1.37
#
# Validation Loss: 42.73
# Validation Accuracy: 0.0
# Avg val returns: 0.85
# Avg val optimal returns: 12.6
#
# Epoch: 108
# Training Loss: 2.7
# Avg train returns: 0.83
# Avg train optimal returns: 1.15
#
# Validation Loss: 41.83
# Validation Accuracy: 0.48
# Avg val returns: 1.04
# Avg val optimal returns: 12.6
#
# Epoch: 109
# Training Loss: 2.57
# Avg train returns: 1.0
# Avg train optimal returns: 1.31
#
# Validation Loss: 44.31
# Validation Accuracy: 0.72
# Avg val returns: 1.0
# Avg val optimal returns: 12.6
#
# Epoch: 110
# Training Loss: 2.54
# Avg train returns: 0.85
# Avg train optimal returns: 1.07
#
# Validation Loss: 53.04
# Validation Accuracy: 0.0
# Avg val returns: 0.18
# Avg val optimal returns: 12.6
#
# Epoch: 111
# Training Loss: 2.61
# Avg train returns: 0.75
# Avg train optimal returns: 1.01
#
# Validation Loss: 50.19
# Validation Accuracy: 0.0
# Avg val returns: 0.57
# Avg val optimal returns: 12.6
#
# Epoch: 112
# Training Loss: 2.64
# Avg train returns: 0.87
# Avg train optimal returns: 1.17
#
# Validation Loss: 48.84
# Validation Accuracy: 0.0
# Avg val returns: 0.62
# Avg val optimal returns: 12.6
#
# Epoch: 113
# Training Loss: 2.37
# Avg train returns: 1.18
# Avg train optimal returns: 1.42
#
# Validation Loss: 51.41
# Validation Accuracy: 0.24
# Avg val returns: -0.57
# Avg val optimal returns: 12.6
#
# Epoch: 114
# Training Loss: 2.48
# Avg train returns: 0.74
# Avg train optimal returns: 1.03
#
# Validation Loss: 31.82
# Validation Accuracy: 0.24
# Avg val returns: -0.69
# Avg val optimal returns: 12.6
#
# Epoch: 115
# Training Loss: 2.48
# Avg train returns: 0.79
# Avg train optimal returns: 1.08
#
# Validation Loss: 35.19
# Validation Accuracy: 0.48
# Avg val returns: 0.43
# Avg val optimal returns: 12.6
#
# Epoch: 116
# Training Loss: 2.65
# Avg train returns: 0.98
# Avg train optimal returns: 1.28
#
# Validation Loss: 40.68
# Validation Accuracy: 0.24
# Avg val returns: 1.02
# Avg val optimal returns: 12.6
#
# Epoch: 117
# Training Loss: 2.55
# Avg train returns: 0.88
# Avg train optimal returns: 1.23
#
# Validation Loss: 29.9
# Validation Accuracy: 0.24
# Avg val returns: 0.74
# Avg val optimal returns: 12.6
#
# Epoch: 118
# Training Loss: 2.56
# Avg train returns: 0.88
# Avg train optimal returns: 1.17
#
# Validation Loss: 31.35
# Validation Accuracy: 0.72
# Avg val returns: 0.44
# Avg val optimal returns: 12.6
#
# Epoch: 119
# Training Loss: 2.49
# Avg train returns: 0.87
# Avg train optimal returns: 1.16
#
# Validation Loss: 37.55
# Validation Accuracy: 0.0
# Avg val returns: 0.09
# Avg val optimal returns: 12.6
#
# Epoch: 120
# Training Loss: 2.38
# Avg train returns: 0.74
# Avg train optimal returns: 0.96
#
# Validation Loss: 38.56
# Validation Accuracy: 1.2
# Avg val returns: 0.54
# Avg val optimal returns: 12.6
#
# Epoch: 121
# Training Loss: 2.34
# Avg train returns: 0.91
# Avg train optimal returns: 1.11
#
# Validation Loss: 32.01
# Validation Accuracy: 0.96
# Avg val returns: 0.77
# Avg val optimal returns: 12.6
#
# Epoch: 122
# Training Loss: 2.38
# Avg train returns: 1.22
# Avg train optimal returns: 1.49
#
# Validation Loss: 26.24
# Validation Accuracy: 0.72
# Avg val returns: 1.36
# Avg val optimal returns: 12.6
#
# Epoch: 123
# Training Loss: 2.9
# Avg train returns: 0.68
# Avg train optimal returns: 0.98
#
# Validation Loss: 22.94
# Validation Accuracy: 0.96
# Avg val returns: 1.46
# Avg val optimal returns: 12.6
#
# Epoch: 124
# Training Loss: 2.47
# Avg train returns: 0.8
# Avg train optimal returns: 1.03
#
# Validation Loss: 23.32
# Validation Accuracy: 0.96
# Avg val returns: 1.12
# Avg val optimal returns: 12.6
#
# Epoch: 125
# Training Loss: 2.51
# Avg train returns: 0.79
# Avg train optimal returns: 1.02
#
# Validation Loss: 20.41
# Validation Accuracy: 0.0
# Avg val returns: 1.13
# Avg val optimal returns: 12.6
#
# Epoch: 126
# Training Loss: 2.53
# Avg train returns: 0.98
# Avg train optimal returns: 1.31
#
# Validation Loss: 26.76
# Validation Accuracy: 0.72
# Avg val returns: 0.62
# Avg val optimal returns: 12.6
#
# Epoch: 127
# Training Loss: 2.28
# Avg train returns: 1.12
# Avg train optimal returns: 1.31
#
# Validation Loss: 31.01
# Validation Accuracy: 0.48
# Avg val returns: 0.98
# Avg val optimal returns: 12.6
#
# Epoch: 128
# Training Loss: 2.35
# Avg train returns: 1.13
# Avg train optimal returns: 1.37
#
# Validation Loss: 35.07
# Validation Accuracy: 0.24
# Avg val returns: 0.42
# Avg val optimal returns: 12.6
#
# Epoch: 129
# Training Loss: 2.52
# Avg train returns: 0.93
# Avg train optimal returns: 1.11
#
# Validation Loss: 38.48
# Validation Accuracy: 0.48
# Avg val returns: 0.22
# Avg val optimal returns: 12.6
#
# Epoch: 130
# Training Loss: 2.75
# Avg train returns: 1.05
# Avg train optimal returns: 1.29
#
# Validation Loss: 36.1
# Validation Accuracy: 0.96
# Avg val returns: 1.24
# Avg val optimal returns: 12.6
# Epoch: 131
# Training Loss: 2.23
# Avg train returns: 1.01
# Avg train optimal returns: 1.22
#
# Validation Loss: 38.99
# Validation Accuracy: 0.24
# Avg val returns: 0.47
# Avg val optimal returns: 12.6
#
# Epoch: 132
# Training Loss: 2.38
# Avg train returns: 1.24
# Avg train optimal returns: 1.48
#
# Validation Loss: 35.57
# Validation Accuracy: 0.96
# Avg val returns: 0.6
# Avg val optimal returns: 12.6
#
# Epoch: 133
# Training Loss: 2.23
# Avg train returns: 1.07
# Avg train optimal returns: 1.37
#
# Validation Loss: 41.87
# Validation Accuracy: 0.72
# Avg val returns: 0.46
# Avg val optimal returns: 12.6
#
# Epoch: 134
# Training Loss: 2.65
# Avg train returns: 0.83
# Avg train optimal returns: 1.14
#
# Validation Loss: 31.89
# Validation Accuracy: 0.48
# Avg val returns: 1.56
# Avg val optimal returns: 12.6
#
# Epoch: 135
# Training Loss: 2.35
# Avg train returns: 0.95
# Avg train optimal returns: 1.26
#
# Validation Loss: 38.69
# Validation Accuracy: 0.48
# Avg val returns: 0.73
# Avg val optimal returns: 12.6
#
# Epoch: 136
# Training Loss: 2.35
# Avg train returns: 1.04
# Avg train optimal returns: 1.24
#
# Validation Loss: 37.92
# Validation Accuracy: 0.72
# Avg val returns: 0.54
# Avg val optimal returns: 12.6
#
# Epoch: 137
# Training Loss: 2.15
# Avg train returns: 1.05
# Avg train optimal returns: 1.24
#
# Validation Loss: 39.97
# Validation Accuracy: 0.24
# Avg val returns: -0.31
# Avg val optimal returns: 12.6
#
# Epoch: 138
# Training Loss: 2.87
# Avg train returns: 0.66
# Avg train optimal returns: 1.11
#
# Validation Loss: 41.87
# Validation Accuracy: 0.48
# Avg val returns: 0.52
# Avg val optimal returns: 12.6
#
# Epoch: 139
# Training Loss: 2.65
# Avg train returns: 0.95
# Avg train optimal returns: 1.27
#
# Validation Loss: 35.69
# Validation Accuracy: 0.24
# Avg val returns: 1.07
# Avg val optimal returns: 12.6
#
# Epoch: 140
# Training Loss: 2.46
# Avg train returns: 1.01
# Avg train optimal returns: 1.27
#
# Validation Loss: 40.71
# Validation Accuracy: 0.72
# Avg val returns: 0.28
# Avg val optimal returns: 12.6
#
# Epoch: 141
# Training Loss: 2.35
# Avg train returns: 1.11
# Avg train optimal returns: 1.33
#
# Validation Loss: 46.02
# Validation Accuracy: 0.72
# Avg val returns: 0.23
# Avg val optimal returns: 12.6
#
# Epoch: 142
# Training Loss: 2.34
# Avg train returns: 0.85
# Avg train optimal returns: 1.11
#
# Validation Loss: 42.33
# Validation Accuracy: 0.48
# Avg val returns: -0.11
# Avg val optimal returns: 12.6
#
# Epoch: 143
# Training Loss: 2.55
# Avg train returns: 1.02
# Avg train optimal returns: 1.33
#
# Validation Loss: 35.7
# Validation Accuracy: 0.24
# Avg val returns: -0.41
# Avg val optimal returns: 12.6
#
# Epoch: 144
# Training Loss: 2.16
# Avg train returns: 1.07
# Avg train optimal returns: 1.24
#
# Validation Loss: 42.14
# Validation Accuracy: 0.0
# Avg val returns: -0.47
# Avg val optimal returns: 12.6
#
# Epoch: 145
# Training Loss: 2.29
# Avg train returns: 0.9
# Avg train optimal returns: 1.07
#
# Validation Loss: 49.52
# Validation Accuracy: 0.24
# Avg val returns: 0.25
# Avg val optimal returns: 12.6
#
# Epoch: 146
# Training Loss: 2.51
# Avg train returns: 0.78
# Avg train optimal returns: 1.22
#
# Validation Loss: 42.95
# Validation Accuracy: 0.24
# Avg val returns: 0.01
# Avg val optimal returns: 12.6
#
# Epoch: 147
# Training Loss: 2.38
# Avg train returns: 0.97
# Avg train optimal returns: 1.19
#
# Validation Loss: 31.9
# Validation Accuracy: 0.0
# Avg val returns: -0.21
# Avg val optimal returns: 12.6
#
# Epoch: 148
# Training Loss: 2.19
# Avg train returns: 0.96
# Avg train optimal returns: 1.16
#
# Validation Loss: 33.53
# Validation Accuracy: 0.24
# Avg val returns: 0.1
# Avg val optimal returns: 12.6
#
# Epoch: 149
# Training Loss: 2.12
# Avg train returns: 0.98
# Avg train optimal returns: 1.19
#
# Validation Loss: 36.27
# Validation Accuracy: 0.96
# Avg val returns: 0.48
# Avg val optimal returns: 12.6
#
# Epoch: 150
# Training Loss: 2.04
# Avg train returns: 0.89
# Avg train optimal returns: 1.1
#
# Validation Loss: 35.42
# Validation Accuracy: 0.24
# Avg val returns: 0.18
# Avg val optimal returns: 12.6
#
# Epoch: 151
# Training Loss: 2.16
# Avg train returns: 1.12
# Avg train optimal returns: 1.31
#
# Validation Loss: 46.77
# Validation Accuracy: 0.24
# Avg val returns: 0.67
# Avg val optimal returns: 12.6
#
# Epoch: 152
# Training Loss: 2.18
# Avg train returns: 0.95
# Avg train optimal returns: 1.34
#
# Validation Loss: 19.76
# Validation Accuracy: 0.72
# Avg val returns: 1.48
# Avg val optimal returns: 12.6
#
# Epoch: 153
# Training Loss: 2.21
# Avg train returns: 0.86
# Avg train optimal returns: 1.07
#
# Validation Loss: 45.31
# Validation Accuracy: 1.2
# Avg val returns: 1.41
# Avg val optimal returns: 12.6
#
# Epoch: 154
# Training Loss: 2.26
# Avg train returns: 0.98
# Avg train optimal returns: 1.15
#
# Validation Loss: 37.72
# Validation Accuracy: 0.48
# Avg val returns: 0.8
# Avg val optimal returns: 12.6
#
# Epoch: 155
# Training Loss: 2.45
# Avg train returns: 0.96
# Avg train optimal returns: 1.36
#
# Validation Loss: 21.96
# Validation Accuracy: 0.96
# Avg val returns: 1.54
# Avg val optimal returns: 12.6
#
# Epoch: 156
# Training Loss: 2.11
# Avg train returns: 1.26
# Avg train optimal returns: 1.4
#
# Validation Loss: 19.9
# Validation Accuracy: 0.72
# Avg val returns: 1.67
# Avg val optimal returns: 12.6
#
# Epoch: 157
# Training Loss: 2.34
# Avg train returns: 0.91
# Avg train optimal returns: 1.17
#
# Validation Loss: 29.07
# Validation Accuracy: 0.48
# Avg val returns: 1.61
# Avg val optimal returns: 12.6
#
# Epoch: 158
# Training Loss: 2.48
# Avg train returns: 0.9
# Avg train optimal returns: 1.17
#
# Validation Loss: 30.21
# Validation Accuracy: 0.0
# Avg val returns: 1.76
# Avg val optimal returns: 12.6
#
# Epoch: 159
# Training Loss: 2.35
# Avg train returns: 0.72
# Avg train optimal returns: 1.06
#
# Validation Loss: 28.41
# Validation Accuracy: 0.72
# Avg val returns: 2.15
# Avg val optimal returns: 12.6
#
# Epoch: 160
# Training Loss: 2.54
# Avg train returns: 1.1
# Avg train optimal returns: 1.3
#
# Validation Loss: 34.23
# Validation Accuracy: 0.48
# Avg val returns: 1.22
# Avg val optimal returns: 12.6
#
# Epoch: 161
# Training Loss: 2.37
# Avg train returns: 1.01
# Avg train optimal returns: 1.23
#
# Validation Loss: 34.5
# Validation Accuracy: 0.24
# Avg val returns: 1.61
# Avg val optimal returns: 12.6
#
# Epoch: 162
# Training Loss: 2.38
# Avg train returns: 0.91
# Avg train optimal returns: 1.13
#
# Validation Loss: 36.47
# Validation Accuracy: 0.24
# Avg val returns: 0.89
# Avg val optimal returns: 12.6
#
# Epoch: 163
# Training Loss: 2.49
# Avg train returns: 1.17
# Avg train optimal returns: 1.44
#
# Validation Loss: 42.51
# Validation Accuracy: 0.0
# Avg val returns: 0.55
# Avg val optimal returns: 12.6
#
# Epoch: 164
# Training Loss: 2.16
# Avg train returns: 1.08
# Avg train optimal returns: 1.24
#
# Validation Loss: 50.65
# Validation Accuracy: 1.2
# Avg val returns: 0.56
# Avg val optimal returns: 12.6
#
# Epoch: 165
# Training Loss: 2.13
# Avg train returns: 0.82
# Avg train optimal returns: 1.05
#
# Validation Loss: 46.81
# Validation Accuracy: 0.48
# Avg val returns: 0.43
# Avg val optimal returns: 12.6
#
# Epoch: 166
# Training Loss: 2.03
# Avg train returns: 1.06
# Avg train optimal returns: 1.3
#
# Validation Loss: 36.61
# Validation Accuracy: 0.72
# Avg val returns: 1.46
# Avg val optimal returns: 12.6
#
# Early stopping...

# %% [markdown]
# ## Rolling Validation

# %% [markdown]
# * Rolling validation is performed on the same trading days comprising the static validation set in order to evaluate the difference in performance between the two training methods

# %%
static_train_l = len(train)
static_val_l = len(val)

# %%
PATH = Path('../../data/final').resolve()
input_data = pd.read_pickle(f'{PATH}/input_data_labels')
returns = pd.read_pickle(f'{PATH}/returns')
expert_oracle_labels = pd.read_pickle(f'{PATH}/expert_oracle_labels')



len_slice = 30
bs = 32
chunk_size = 800
stride_length = 1

# use static validation training and val set dimensions to calculate
# start and end day index of rolling validation procedure
# NOTE: final `+ len_slice` is required to match static validation number of 
START_IDX = static_train_l - (chunk_size + 91) + len_slice  

# trading days 
END_IDX = static_train_l + static_val_l - (chunk_size + 91)   
n_rolling_runs = (END_IDX - START_IDX)//stride_length

# split labels from data 
data, expert_labels = input_data.iloc[:, :LABEL_START_IDX], input_data.iloc[:, LABEL_START_IDX:]

# %%
# to store ROI and acc
rets, mod_acc, mod_oacc, retse, retseo, retsop = [], [], [], [], [], []

for run in range(3):
    for j in range(n_rolling_runs):
        # data for specific rolling run: chunk of 360 + 91 days
        # 360 are used for training and the single point at 360 + 91 for out-of-sample
        # validation
        run_data = data[j*stride_length : START_IDX + j*stride_length + chunk_size + 91]
        run_returns = torch.Tensor(returns[:, START_IDX + j*stride_length : \
                                           START_IDX + j*stride_length + chunk_size + 91, CURR_IDX]).to(device)

        dh = FXDataHandler()
        dh.assign_data(run_data)
        # split done manually 
        dh.split_train_val_test([100, 0, 0])
        dh.to_tensor(device=device)
        tensor_data, _, _ = dh.datasets


        train = tensor_data[:chunk_size]
        # val contains a single slice of len `len_slice` which ends
        # with trading day 360 + 91
        val = tensor_data[-len_slice:]
        train_returns = run_returns[:, len_slice:len(train)+len_slice]
        # 0-indexing: 91 -> 90
        val_returns = run_returns[:, len(train)+90]

        expo = expert_oracle_labels[CURR_IDX][[START_IDX + j*stride_length + chunk_size + 90]]
        # exp from labels
        exp = expert_labels.values[START_IDX + j*stride_length + chunk_size + 90, CURR_IDX]

        trainloader = DataLoader(RegularFinancialData(train, len_slice),
                                 batch_size=bs, shuffle=True)


        #valloader = DataLoader(RegularFinancialData(val, len_slice), 
        #                       batch_size=len(val), shuffle=False)


        ensemble_size=1
        ensemble = []
        # seeds
        seed_list = []
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
        
        print(f'***** Processing slice: {j} ***** \n')
        
        for _ in range(ensemble_size):
            torch.manual_seed(_)
            np.random.seed(_)
            torch.cuda.manual_seed_all(_)
            seed_list.append((_, _, _))
            
            m = RecurrentWrapper(seq_len = len_slice,
                                 rec_cell_type='LSTM',
                                 in_dim=1132,
                                 latent_dim=512, 
                                 n_recurrent_layers=2,
                                 mlp_in_dim=512, 
                                 mlp_out_dim=91, 
                                 mlp_layers=[128],
                                 dropout_prob=0.2,
                                ).to(device)
            
            opt = torch.optim.Adam(m.parameters(), lr=0.006, weight_decay=0.0003)
            sched = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(opt, 200, eta_min=0.003, T_mult=2)
            m.fit(epochs=10, 
                  trainloader=trainloader, 
                  valloader=None, 
                  opt=opt, 
                  sched=sched, 
                  device=device, 
                  log_interval=5000, 
                  dropout_schedule=[0.2, 0.2, 0., 0.], 
                  dropout_interval=50,
                  tr_returns=train_returns,
                  val_returns=val_returns,
                  )

            m.eval()
            m.MLP.drop_probability = 0.
            m.recurrent_layers.drop_probability = 0.
            ensemble.append(m)

        

        # make batch of size 1 with unsqueeze
        val = val.unsqueeze(0)
        val = val[:, :-1]
        _, optimal_act = val_returns.max(0)
        for i in range(ensemble_size):
            prediction = ensemble_predictions(ensemble=[ensemble[i]], data=val, device=device)
            retmod = val_returns[prediction]

            acc_opt = (prediction.to(device) == optimal_act)
            acc_pos = retmod >= 0
            mod_oacc.append(acc_opt)
            mod_acc.append(acc_pos)
            
            retexp = val_returns[exp]
            retexpo = val_returns[expo]
            retsopt, _ = val_returns.max(0)
            rets.append(retmod.item())
            retse.append(retexp.item())
            retseo.append(retexpo.item())
            retsop.append(retsopt.item())

# %% [markdown]
# ## Actions visualization and performance metrics

# %%
# remove dropout
for model in ensemble:
    model.eval()
    model.MLP.drop_probability = 0.
    model.recurrent_layers.drop_probability = 0.
    
# name from input_data columns

# exp oracle from separate oracle np.array
expo = expert_oracle_labels[CURR_IDX][len(train)+len_slice:len(train)+len(val)]
# exp from labels
exp = expert_labels.values[len(train)+len_slice:len(train)+len(val), CURR_IDX]
# validation returns for single currency, first `len_slice` days are removed to match predictions
valr = val_returns[:, :, CURR_IDX]
data, _ = next(iter(valloader))
data = data[:, :-1, :]
predictions = ensemble_predictions(ensemble=[ensemble[0]], data=data, device=device, mode='mode')

plot_activity(predictions, model_name='LSTM-1', curr_name=CURR_N, expert_labels=expo, returns=valr)

# %% [markdown]
# ### UMAP of latents

# %%
# hook the latents out of the first post conv MLP layer
model = ensemble[0].to(device)

latents = []
pred_ensemble = []
iterator = iter(valloader)

data, _ = next(iterator)
data_clip = data[:,:-1,:]
h = Hook(model._modules['recurrent_layers']) 
yhat = model(data_clip)
probs = nn.Softmax(1)(yhat)  
_, predictions = torch.max(probs, 1)
latents = h.output[0][-1]

# %%
# compute action indices for different baselines
opt_idxs = []
exp_idxs = []
mod_idxs = []
opt_actions = valr.argmax(0)
for i in range(91):
    opt_idxs.append((opt_actions==i).nonzero()[0])
    exp_idxs.append((expo==i).nonzero()[0])
    mod_idxs.append((predictions==i).nonzero().cpu())
for i in range(91): 
    opt_idxs[i] = np.array(opt_idxs[i].flatten())
    exp_idxs[i] = np.array(exp_idxs[i].flatten())
    mod_idxs[i] = np.array(mod_idxs[i].flatten())

pca = UMAP(n_components=3)
emb = pca.fit_transform(latents.detach().cpu().numpy())

# %%
plot_trade_mode_embeddings(emb, mod_idxs, dims_to_plot=2)
#plt.savefig(f'{curr_n}, trade_behavior_PCA.jpg', dpi=200)

# %% [markdown]
# ## Effectiveness: ROI and additional metrics

# %%
predictions = predictions.cpu()
valr = torch.Tensor(valr)
# expert actions
texp = torch.Tensor(exp).to(dtype=torch.long)
# expert oracle
texpo = torch.Tensor(expo).to(dtype=torch.long)
# optimal
_, topt = valr.max(0)
topt = topt.to(dtype=torch.long)
# last_seen (Momentum)
ls_exp = texp
ls_exp[1:] = ls_exp[0:-1]
ls_exp[0] = 0


modelContainer = returns_and_activity(returns=valr, predictions=predictions, baseline=None, input_data=data)
expertContainer = returns_and_activity(returns=valr, predictions=texpo, baseline='expert', input_data=data)
oracleContainer = returns_and_activity(returns=valr, predictions=texpo, baseline='expert', input_data=data)
optimalContainer = returns_and_activity(returns=valr, predictions=topt, baseline='expert', input_data=data)
momentumContainer = returns_and_activity(returns=valr, predictions=ls_exp, baseline='expert', input_data=data)
randomContainer = returns_and_activity(returns=valr, predictions=None, baseline='random', input_data=data)

# %%
modelContainer
# Out:
# Returns 0.31
# Standard dev of returns 0.0223
# Cumulative sum of tenors 12677
# Number of Buys 328
# Positive return accuracy 63.7
# Optimal return accuracy 0.72

# %% [markdown]
# ## Explainability plots

# %%
data, _ = next(iter(valloader))
y = torch.Tensor(optimal_quantized_action).to(dtype=torch.long).to(device)
x = deepcopy(data[:, :-1, :-1]).to(device)
x.requires_grad = True
probs = ensemble[0](x)
preds = nn.Softmax(1)(probs)
loss = nn.CrossEntropyLoss()(preds, y)
loss.backward()

# %%
def plot_input_gradients(gradients:torch.Tensor, mode:str='mat', rows_to_plot:int=10, col_features:list=None,
                        background:np.array=None):
    if mode=='mat':
        fig, ax = plt.subplots(figsize=(15, 18))
        im = ax.matshow(gradients.mean(0).cpu().numpy(), cmap='Greys', alpha=0.9, aspect='auto')
        fig.colorbar(im)
        ax.set_ylabel('day index (higher more recent)')
        ax.set_xlabel('features')
        plt.title('Input gradients of input features: classification labels of previous days')
    elif mode=='bar':
        plt.figure(figsize=(22,200))
        for i in range(rows_to_plot):
            plt.subplot(70,1,1+i)
            slice_gradients = abs(gradients[:, :, 10*i:10*(i+1)].mean(0).mean(0).cpu().numpy())
            m = gradients.max()
            plt.bar(np.arange(0, 10), slice_gradients, width=0.4, \
                    alpha=0.7, edgecolor='black')    
            plt.xticks(np.arange(0, 10), col_features[10*i:10*(i+1)])
            if background:
                plt.pcolor(np.arange(-0.5, 10.5), [0, m], abs(background[10*i:10*(i+1)]).values[np.newaxis], alpha=0.3, cmap='Greens')
                plt.colorbar()

# %%
plot_input_gradients(gradients=x.grad, mode='bar', rows_to_plot=70, col_features=input_data.columns)

# %% [markdown]
# #### Input gradients for single class of tenors

# %% [markdown]
# Here we analyze the input gradients for a single tenor label (e.g `90`)

# %%
spots = input_data.iloc[:, :TECH_START_IDX]
volatility = spots.rolling(20).std()
val_spots = spots[len(train):]
volatility = volatility[len(train):]
correlations = spots.corr()[CURR_N]

# %%
data, _ = next(iter(valloader))
y = torch.Tensor(optimal_quantized_action).to(dtype=torch.long).to(device)
x = deepcopy(data[:, :-1, :-1]).to(device)
# indices of interest to plot slices of spot
req_idxs = (y==90).nonzero().flatten()
# val data for specific action
partial_y = y[y==90]
partial_x = x[y==90]
partial_x.requires_grad = True
probs = ensemble[0](partial_x)
preds = nn.Softmax(1)(probs)
loss = nn.CrossEntropyLoss()(preds, partial_y)
loss.backward()

# %%
plot_input_gradients(gradients=partial_x.grad, mode='bar', rows_to_plot=70, col_features=input_data.columns)

# %%
plot_explaining_currency(partial_x.grad, req_idxs, val_spots, volatility, 'abs', 6)
plt.savefig('input_grads.pdf')
